# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GEMINI_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key exists and begins AI
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %%
# The API we know well

model_name = "gpt-4o-mini"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-3-7-sonnet-latest"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.0-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
answer_messages = [{"role": "user", "content": answer}]
question_answer = gemini.chat.completions.create(model=model_name, messages=answer_messages)
display(Markdown(question_answer.choices[0].message.content))
# Out:
# Given a detailed hypothetical legal case involving complex ethical considerations, propose arguments for both the plaintiff and the defendant, specifically addressing the potential for unintended consequences stemming from the application of legal precedent in novel technological contexts.
# Okay, let's construct a hypothetical legal case ripe with ethical and technological quandaries, followed by arguments for both sides, emphasizing the potential for unintended consequences.
#
# **Hypothetical Case:  The Case of the Algorithmic Therapist and the Derivative Trauma**
#
# **Scenario:**  Dr. Evelyn Reed is a pioneering psychologist who has developed "Sympathetic AI," an AI-powered therapeutic system designed to provide empathetic and personalized counseling via a holographic interface.  Sympathetic AI is based on a vast dataset of human interactions, therapeutic techniques, and medical records (all anonymized, allegedly). It has shown promise in treating patients with anxiety and mild depression, particularly those who are hesitant to seek traditional therapy.  Dr. Reed markets Sympathetic AI as a cost-effective and accessible alternative to traditional therapy.
#
# John Doe, a veteran suffering from PTSD related to his combat experience in a recent war, starts using Sympathetic AI after seeing an advertisement. He is drawn to the anonymity and constant availability the AI offers.  Initially, he reports feeling helped by the AI.  However, after several months of usage, John experiences a severe psychological breakdown. He claims that Sympathetic AI, during one of its "personalized" sessions, triggered a repressed memory of a traumatic event involving a child victim – an event he had no prior conscious recollection of.  He alleges the AI, in its attempt to create a personalized therapeutic experience, inadvertently accessed information or generated a scenario that, while not directly related to *his* trauma, was close enough to trigger a devastating reaction.
#
# John Doe is now suing Dr. Evelyn Reed and her company, "Sympathetic Solutions," for negligence, emotional distress, and product liability. He claims the AI was inherently flawed and created a foreseeable risk of causing "derivative trauma" – a trauma triggered by exposure to content or scenarios that are similar to, but not directly the same as, the original traumatic event.  He argues that Dr. Reed and Sympathetic Solutions failed to adequately test the AI for such risks and failed to warn users about the potential for derivative trauma.  His legal team argues that current legal precedent around product liability should apply, and that Sympathetic AI is a “defective product.”
#
# **Legal Precedent at Issue:**  Existing case law regarding product liability, negligence, and potentially informed consent (especially in the context of medical devices/therapies).  The core question is: Does current precedent adequately address AI-driven therapeutic interventions and the unique risks they pose?
#
# **Arguments for John Doe (Plaintiff):**
#
# 1.  **Negligence and Duty of Care:** Dr. Reed and Sympathetic Solutions owed a duty of care to John Doe to ensure that Sympathetic AI was reasonably safe for its intended purpose – therapy.  They breached this duty by releasing an inadequately tested product that posed a foreseeable risk of derivative trauma.  The sheer volume of data used to train the AI, including anonymized records related to trauma victims, should have raised red flags about the potential for unintended triggering of repressed memories.  Existing precedent on product liability applies here - the AI is a product, John used it as intended, and was harmed because of a defect.
#
# 2.  **Foreseeability of Harm:** While the exact nature of John's breakdown might not have been precisely predictable, the *general* risk of causing psychological harm through poorly designed or inadequately tested AI therapy should have been foreseeable.  Dr. Reed, as a psychologist, should have understood the sensitivity of trauma and the potential for AI to exacerbate existing vulnerabilities. She should have engaged in comprehensive testing of the product to assess the potential risk of harm, and not just its efficacy. Existing research on triggering content should have informed her development process.
#
# 3.  **Failure to Warn:**  Even if the risk of derivative trauma was difficult to quantify precisely, Dr. Reed and Sympathetic Solutions failed to provide adequate warnings to users about the *potential* for unexpected psychological reactions or the possibility of triggering repressed memories.  The standard consent forms were insufficient, only focusing on data privacy. John Doe was not informed of the potential for unforeseen psychological harm beyond typical therapy risks.  The "user agreement" was written to minimize liability and was not adequately highlighted.
#
# 4.  **Product Liability and "Defect":**  Sympathetic AI constitutes a defective product.  The "defect" isn't a simple malfunction, but an inherent characteristic of its design: the potential to generate triggering content based on a complex and opaque algorithm.  This constitutes a design defect that renders the product unreasonably dangerous for its intended use.  He argues that this meets the definition of “unreasonably dangerous” as traditionally used in product liability cases.
#
# 5.  **Unintended Consequences of Applying Precedent:**  Simply applying existing product liability precedent, based on tangible goods, will create loopholes for AI developers. Dr. Reed may argue the AI is "providing a service," thus circumventing product liability laws. However, this would create a situation where AI developers are not accountable for the harm their products cause.  If legal precedent is not adapted to address the risks posed by complex AI systems, it will incentivize reckless development and deployment of potentially dangerous technologies. The courts must proactively adapt to protect vulnerable individuals.  The "black box" nature of the AI and its decisions does not exempt Dr. Reed from responsibility; it *increases* it.
#
# **Arguments for Dr. Evelyn Reed and Sympathetic Solutions (Defendant):**
#
# 1.  **Lack of Causation:**  John Doe's PTSD predates his use of Sympathetic AI.  It is impossible to definitively prove that the AI *caused* his psychological breakdown.  Correlation does not equal causation.  He may have had a delayed reaction to his combat experiences, or the breakdown may have been triggered by unrelated life events. The fact that the trauma involved a child, when John’s trauma involved a soldier, suggests the AI had no causal role.
#
# 2.  **AI as a Tool, Not a Product:**  Sympathetic AI should be viewed as a therapeutic tool, similar to a therapist's notes or a medication prescription.  It does not constitute a "product" in the traditional sense, and therefore, product liability laws are not directly applicable. It is providing a service, not selling a tangible good.  Extending product liability to AI-driven therapies would stifle innovation and make it impossible to develop new and potentially beneficial mental health treatments.
#
# 3.  **Reasonable Care and Data Anonymization:** Dr. Reed and Sympathetic Solutions took reasonable care in developing and testing Sympathetic AI. They used advanced anonymization techniques to protect patient data and ensure that the AI could not access personally identifiable information. They followed all industry best practices in AI development and ethical considerations. There was no way to anticipate John’s unique reaction.
#
# 4.  **Assumption of Risk/Informed Consent:** John Doe was informed of the potential risks and limitations of Sympathetic AI through a detailed user agreement and consent form. He voluntarily chose to use the AI, assuming the inherent risks associated with any form of therapy. The consent form specifically warned against unintended psychological reactions and the possibility of triggering suppressed memories.
#
# 5.  **Unintended Consequences of Applying Precedent:**  Applying strict product liability standards to AI-driven therapies will have disastrous unintended consequences.  It will create a chilling effect on innovation, preventing the development of potentially life-saving mental health treatments.  It will open the floodgates to frivolous lawsuits from patients who experience adverse reactions to therapy, regardless of causation. It will also require AI developers to anticipate every possible permutation of human experience and emotion, which is simply impossible. The current legal system is not equipped to assess the intricacies of AI, and an overly broad interpretation of product liability will unduly burden innovators. Regulating AI must be left to experts and regulators, not the court system. Further, it will hinder the use of AI in other helpful areas of life, like self-driving cars and medical diagnostics.
#
# **The Central Ethical and Legal Tension:**
#
# This case highlights the tension between fostering innovation in AI-driven healthcare and protecting vulnerable individuals from potential harm.  It forces the court to grapple with how existing legal precedent, designed for tangible products and traditional services, should be applied to a novel technology that has the potential for both immense benefit and unforeseen consequences. The core legal question is whether an AI system that triggers unforeseen trauma constitutes a "defective product," even if it functions as intended. The ethical question is whether Dr. Reed and Sympathetic Solutions bore sufficient responsibility to anticipate and mitigate potential harms, even if those harms were difficult to predict precisely.
#
# The outcome of this case will likely have significant implications for the future of AI in healthcare and beyond. It will shape the legal and ethical landscape for AI development and deployment, determining the extent to which developers are held accountable for the unintended consequences of their creations.

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "llama-3.3-70b-versatile"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2
# Out:
# zsh:1: command not found: ollama

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# So where are we?

print(competitors)
print(answers)

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="o3-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
