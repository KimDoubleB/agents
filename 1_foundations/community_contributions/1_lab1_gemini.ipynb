# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Treat these labs as a resource</h2>
#             <span style="color:#00bfff;">I push updates to the code regularly. When people ask questions or have problems, I incorporate it in the code, adding more examples or improved commentary. As a result, you'll notice that the code below isn't identical to the videos. Everything from the videos is here; but in addition, I've added more steps and better explanations. Consider this like an interactive book that accompanies the lectures.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Run `uv add google-genai` to install the Google Gemini library. (If you had started your environment before running this command, you will need to restart your environment in the Jupyter notebook.)
# 2. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 3. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 4. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. From the Cursor menu, choose Settings >> VSCode Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import
from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables

load_dotenv(override=True)
# Out:
# True

# %%
# Check the keys

import os
gemini_api_key = os.getenv('GEMINI_API_KEY')

if gemini_api_key:
    print(f"Gemini API Key exists and begins {gemini_api_key[:8]}")
else:
    print("Gemini API Key not set - please head to the troubleshooting guide in the guides folder")
# Out:
# Gemini API Key exists and begins AIzaSyAt

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting guide

from google import genai

# %%
# And now we'll create an instance of the Gemini GenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder!
# If you get a NameError - head over to the guides folder to learn about NameErrors

client = genai.Client(api_key=gemini_api_key)

# %%
# Create a list of messages in the familiar Gemini GenAI format

messages = ["What is 2+2?"]

# %%
# And now call it! Any problems, head to the troubleshooting guide

response = client.models.generate_content(
    model="gemini-2.0-flash", contents=messages
)

print(response.text)
# Out:
# 2 + 2 = 4

# %%
# Lets no create a challenging question
question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."

# Ask the the model
response = client.models.generate_content(
    model="gemini-2.0-flash", contents=question
)

# %%
question = response.text
print(question)
# Out:
# Imagine a perfectly elastic billiard ball on a frictionless, circular table. You strike the ball from the edge, aiming it inwards at an arbitrary angle. Describe, with mathematical precision and justification, the conditions under which the ball will eventually return to its exact starting point.

# %%
# Ask the models generated question to the model
response = client.models.generate_content(
    model="gemini-2.0-flash", contents=question
)

# Extract the answer from the response
answer = response.text

# Debug log the answer
print(answer)
# Out:
# Okay, here's a detailed analysis of the billiard ball trajectory on a frictionless, circular table, focusing on the conditions required for it to return to its starting point:
#
# **Coordinate System and Initial Conditions**
#
# *   **Origin:** Center of the circular table.
# *   **Radius:** `R`.
# *   **Starting Point:** Let's place the starting point at coordinates `(R, 0)`.  This simplifies the initial angle definition.
# *   **Initial Velocity:** The ball is struck with initial speed `v`. The initial velocity vector can be expressed as `v = (v*cos(θ), v*sin(θ))`, where `θ` is the angle between the ball's initial direction and the positive x-axis (measured counterclockwise). Crucially, `θ` must be between -π/2 and π/2 for the ball to initially move inwards.
#
# **Trajectory Analysis**
#
# 1.  **Linear Motion Between Collisions:**  Because there's no friction, the ball will travel in a straight line at a constant speed `v` between collisions with the edge of the table.
#
# 2.  **Reflection at the Edge:** At each point of contact with the edge, the ball undergoes a perfectly elastic collision. This means:
#     *   The magnitude of the velocity (`v`) remains constant.
#     *   The component of the velocity *tangential* to the edge remains unchanged.
#     *   The component of the velocity *normal* (radial) to the edge is reversed.
#
# 3.  **Angles and Isosceles Triangles:** Key to understanding the trajectory is that after each bounce, the angle of incidence (the angle between the trajectory and the radius line at the point of impact) *always equals* the angle of reflection. Also, since the radius is constant, the line segment joining the centre of the circle to two consecutive points of collision with the edge are of equal length. Thus any two consecutive points of contact with the edge, and the centre of the circle, define an isoceles triangle. This means that the angle subtended at the centre of the circle by any line segment joining two consecutive points of collision on the edge is equal to 2 * incidence angle.
#
# **Condition for Returning to the Starting Point**
#
# For the ball to return to the starting point, its trajectory must form a closed polygon inscribed within the circle.  Let's say the ball completes `n` bounces before returning to the starting point. The path of the ball consists of `n` equal chords on the circle. Since the chords are equal, they subtend equal angles at the center. Also, `n` line segments joining the centre of the circle to the points of collision on the edge form `n` isoceles triangles of equal shape.
#
# Let α be the angle subtended at the centre of the circle by each segment of the path. For the trajectory to close and return to the starting point, we need the sum of these angles to be a multiple of 2π. Therefore, we require:
#
# `n * α = 2π * k`
#
# where:
# *   `n` is the number of bounces.
# *   `α` is the angle subtended at the centre by each path segment.
# *   `k` is an integer (representing the number of full revolutions around the center).
#
# Since the angle α is double the angle of incidence, and θ is the original angle between the ball's initial direction and the positive x-axis, the initial angle θ is related to the incident angle. Let's express α in terms of θ.
# If the angle from the positive x-axis to the point of collision with the edge is ϕ, then the gradient of the line joining the centre of the circle to the point of collision is tan(ϕ).
#
# **Critical Relationship**
#
# Each bounce contributes to the total rotation around the circle. The total angular displacement `nα` must be equal to a multiple of `2π` for the trajectory to close. Thus:
#
# `nα = 2πk`  (where *k* is an integer representing the number of complete circuits around the circle).
#
# Substituting `α` in terms of θ, we get:
#
# `n * (π - 2θ) = 2πk`
#
# Rearranging for θ:
#
# `nπ - 2nθ = 2πk`
#
# `2nθ = nπ - 2πk`
#
# `θ = (n - 2k)π / (2n)`
#
# Therefore, the condition for the ball to return to its starting point after `n` bounces is that the initial angle `θ` must satisfy:
#
# **`θ = (n - 2k)π / (2n)`**
#
# where:
#
# *   `n` is the number of bounces (an integer, n ≥ 1).
# *   `k` is an integer representing the number of full revolutions around the center (0 ≤ k < n/2). We require that `k < n/2` to ensure θ is between -π/2 and π/2
#
# **Interpretation and Implications**
#
# *   **Rationality:** The angle `θ` must be a rational multiple of `π`.  This means `θ` must be expressible as a fraction `a/b` multiplied by `π`, where `a` and `b` are integers.
#
# *   **Special Cases:**
#
#     *   `n = 1`:  `θ = (1 - 2k)π / 2`.  Since `0 <= k < 1/2`, then k must be 0 and `θ = π / 2`. This corresponds to hitting the ball directly towards the center. It goes to the opposite side and bounces back.
#     *   `n = 2`: `θ = (2 - 2k)π / 4 = (1-k)π/2`. Since `0 <= k < 1`, then `k = 0`. `θ = π / 2`. Same as above.
#     *   `n = 3`: `θ = (3 - 2k)π / 6`. Since `0 <= k < 1.5`, then `k = 0 or 1`.
#         *   `k = 0`: `θ = π/2`. The ball will hit the opposite side and return.
#         *   `k = 1`: `θ = π/6`.
#
# *   **Density:** The set of angles that satisfy this condition is dense in the interval `(-π/2, π/2)`.  This means you can get arbitrarily close to any angle with one that allows the ball to return.
#
# *   **Sensitivity:** Because of the rational constraint, a slight deviation from the precisely calculated `θ` will result in a trajectory that doesn't return to the starting point. The ball will instead trace a different closed path or eventually cover the table surface.
#
# **In Summary**
#
# For a perfectly elastic billiard ball on a frictionless, circular table to return to its exact starting point after being struck from the edge, the initial angle of the ball's trajectory (measured counterclockwise from the radial line at the starting point) must be a rational multiple of `π` given by the formula:  `θ = (n - 2k)π / (2n)`, where `n` is the number of bounces and `k` is an integer between 0 (inclusive) and n/2 (exclusive). This angle condition creates a closed, regular polygon inscribed within the circle. Any deviation from this precise angle will result in a non-returning trajectory.

# %%
from IPython.display import Markdown, display

# Nicely format the answer using Markdown
display(Markdown(answer))
# Out:
# Okay, here's a detailed analysis of the billiard ball trajectory on a frictionless, circular table, focusing on the conditions required for it to return to its starting point:
#
# **Coordinate System and Initial Conditions**
#
# *   **Origin:** Center of the circular table.
# *   **Radius:** `R`.
# *   **Starting Point:** Let's place the starting point at coordinates `(R, 0)`.  This simplifies the initial angle definition.
# *   **Initial Velocity:** The ball is struck with initial speed `v`. The initial velocity vector can be expressed as `v = (v*cos(θ), v*sin(θ))`, where `θ` is the angle between the ball's initial direction and the positive x-axis (measured counterclockwise). Crucially, `θ` must be between -π/2 and π/2 for the ball to initially move inwards.
#
# **Trajectory Analysis**
#
# 1.  **Linear Motion Between Collisions:**  Because there's no friction, the ball will travel in a straight line at a constant speed `v` between collisions with the edge of the table.
#
# 2.  **Reflection at the Edge:** At each point of contact with the edge, the ball undergoes a perfectly elastic collision. This means:
#     *   The magnitude of the velocity (`v`) remains constant.
#     *   The component of the velocity *tangential* to the edge remains unchanged.
#     *   The component of the velocity *normal* (radial) to the edge is reversed.
#
# 3.  **Angles and Isosceles Triangles:** Key to understanding the trajectory is that after each bounce, the angle of incidence (the angle between the trajectory and the radius line at the point of impact) *always equals* the angle of reflection. Also, since the radius is constant, the line segment joining the centre of the circle to two consecutive points of collision with the edge are of equal length. Thus any two consecutive points of contact with the edge, and the centre of the circle, define an isoceles triangle. This means that the angle subtended at the centre of the circle by any line segment joining two consecutive points of collision on the edge is equal to 2 * incidence angle.
#
# **Condition for Returning to the Starting Point**
#
# For the ball to return to the starting point, its trajectory must form a closed polygon inscribed within the circle.  Let's say the ball completes `n` bounces before returning to the starting point. The path of the ball consists of `n` equal chords on the circle. Since the chords are equal, they subtend equal angles at the center. Also, `n` line segments joining the centre of the circle to the points of collision on the edge form `n` isoceles triangles of equal shape.
#
# Let α be the angle subtended at the centre of the circle by each segment of the path. For the trajectory to close and return to the starting point, we need the sum of these angles to be a multiple of 2π. Therefore, we require:
#
# `n * α = 2π * k`
#
# where:
# *   `n` is the number of bounces.
# *   `α` is the angle subtended at the centre by each path segment.
# *   `k` is an integer (representing the number of full revolutions around the center).
#
# Since the angle α is double the angle of incidence, and θ is the original angle between the ball's initial direction and the positive x-axis, the initial angle θ is related to the incident angle. Let's express α in terms of θ.
# If the angle from the positive x-axis to the point of collision with the edge is ϕ, then the gradient of the line joining the centre of the circle to the point of collision is tan(ϕ).
#
# **Critical Relationship**
#
# Each bounce contributes to the total rotation around the circle. The total angular displacement `nα` must be equal to a multiple of `2π` for the trajectory to close. Thus:
#
# `nα = 2πk`  (where *k* is an integer representing the number of complete circuits around the circle).
#
# Substituting `α` in terms of θ, we get:
#
# `n * (π - 2θ) = 2πk`
#
# Rearranging for θ:
#
# `nπ - 2nθ = 2πk`
#
# `2nθ = nπ - 2πk`
#
# `θ = (n - 2k)π / (2n)`
#
# Therefore, the condition for the ball to return to its starting point after `n` bounces is that the initial angle `θ` must satisfy:
#
# **`θ = (n - 2k)π / (2n)`**
#
# where:
#
# *   `n` is the number of bounces (an integer, n ≥ 1).
# *   `k` is an integer representing the number of full revolutions around the center (0 ≤ k < n/2). We require that `k < n/2` to ensure θ is between -π/2 and π/2
#
# **Interpretation and Implications**
#
# *   **Rationality:** The angle `θ` must be a rational multiple of `π`.  This means `θ` must be expressible as a fraction `a/b` multiplied by `π`, where `a` and `b` are integers.
#
# *   **Special Cases:**
#
#     *   `n = 1`:  `θ = (1 - 2k)π / 2`.  Since `0 <= k < 1/2`, then k must be 0 and `θ = π / 2`. This corresponds to hitting the ball directly towards the center. It goes to the opposite side and bounces back.
#     *   `n = 2`: `θ = (2 - 2k)π / 4 = (1-k)π/2`. Since `0 <= k < 1`, then `k = 0`. `θ = π / 2`. Same as above.
#     *   `n = 3`: `θ = (3 - 2k)π / 6`. Since `0 <= k < 1.5`, then `k = 0 or 1`.
#         *   `k = 0`: `θ = π/2`. The ball will hit the opposite side and return.
#         *   `k = 1`: `θ = π/6`.
#
# *   **Density:** The set of angles that satisfy this condition is dense in the interval `(-π/2, π/2)`.  This means you can get arbitrarily close to any angle with one that allows the ball to return.
#
# *   **Sensitivity:** Because of the rational constraint, a slight deviation from the precisely calculated `θ` will result in a trajectory that doesn't return to the starting point. The ball will instead trace a different closed path or eventually cover the table surface.
#
# **In Summary**
#
# For a perfectly elastic billiard ball on a frictionless, circular table to return to its exact starting point after being struck from the edge, the initial angle of the ball's trajectory (measured counterclockwise from the radial line at the starting point) must be a rational multiple of `π` given by the formula:  `θ = (n - 2k)π / (2n)`, where `n` is the number of bounces and `k` is an integer between 0 (inclusive) and n/2 (exclusive). This angle condition creates a closed, regular polygon inscribed within the circle. Any deviation from this precise angle will result in a non-returning trajectory.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:
messages = ["AI 에이전트에게 기회가 있는 값진 비즈니스/산업 영역이 뭐가 있을까?"]

# Then make the first call:

response = client.models.generate_content(
    model="gemini-2.5-flash-preview-05-20", contents=messages
)

# Then read the business idea:

business_idea = response.text
print("business_idea: ", business_idea)


# And repeat!

question = f"{business_idea} 영역에서 AI Agent 솔루션을 이용해 해결할 수 있는 pain point들이 있을까?"

response = client.models.generate_content(
    model="gemini-2.5-flash-preview-05-20", contents=question
)

pain_point = response.text
print("response: ", pain_point)

# third
last_question = f"'{pain_point}'에 대해 해결 할 수 있는 AI Agent 솔루션을 제안해줘."

response = client.models.generate_content(
    model="gemini-2.5-flash-preview-05-20", contents=last_question
)

solution = response.text
print("solution: ", solution)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[10], line 6
#       2 messages = ["AI 에이전트에게 기회가 있는 값진 비즈니스/산업 영역이 뭐가 있을까?"]
#       4 # Then make the first call:
# ----> 6 response = client.models.generate_content(
#       7     model="gemini-2.5-flash", contents=messages
#       8 )
#      10 # Then read the business idea:
#      12 business_idea = response.text
#
# File ~/bb/agents/.venv/lib/python3.12/site-packages/google/genai/models.py:6058, in Models.generate_content(self, model, contents, config)
#    6056 while remaining_remote_calls_afc > 0:
#    6057   i += 1
# -> 6058   response = self._generate_content(
#    6059       model=model, contents=contents, config=parsed_config
#    6060   )
#    6061   logger.info(f'AFC remote call {i} is done.')
#    6062   remaining_remote_calls_afc -= 1
#
# File ~/bb/agents/.venv/lib/python3.12/site-packages/google/genai/models.py:5007, in Models._generate_content(self, model, contents, config)
#    5004 request_dict = _common.convert_to_dict(request_dict)
#    5005 request_dict = _common.encode_unserializable_types(request_dict)
# -> 5007 response_dict = self._api_client.request(
#    5008     'post', path, request_dict, http_options
#    5009 )
#    5011 if self._api_client.vertexai:
#    5012   response_dict = _GenerateContentResponse_from_vertex(
#    5013       self._api_client, response_dict
#    5014   )
#
# File ~/bb/agents/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:927, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#     917 def request(
#     918     self,
#     919     http_method: str,
#    (...)    922     http_options: Optional[HttpOptionsOrDict] = None,
#     923 ) -> Union[BaseResponse, Any]:
#     924   http_request = self._build_request(
#     925       http_method, path, request_dict, http_options
#     926   )
# --> 927   response = self._request(http_request, stream=False)
#     928   json_response = response.json
#     929   if not json_response:
#
# File ~/bb/agents/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:793, in BaseApiClient._request(self, http_request, stream)
#     785 else:
#     786   response = self._httpx_client.request(
#     787       method=http_request.method,
#     788       url=http_request.url,
#    (...)    791       timeout=http_request.timeout,
#     792   )
# --> 793   errors.APIError.raise_for_response(response)
#     794   return HttpResponse(
#     795       response.headers, response if stream else [response.text]
#     796   )
#
# File ~/bb/agents/.venv/lib/python3.12/site-packages/google/genai/errors.py:104, in APIError.raise_for_response(cls, response)
#     102 status_code = response.status_code
#     103 if 400 <= status_code < 500:
# --> 104   raise ClientError(status_code, response_json, response)
#     105 elif 500 <= status_code < 600:
#     106   raise ServerError(status_code, response_json, response)
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-2.5-flash is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}
